# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
schema_df = pd.read_csv('schema.csv') 
#schema_df.info()
#schema_df=schema_df.question.iloc[3:]

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
# 5                                 Student, part-time
# 6                                I prefer not to say
# 7                                 Student, full-time
# 8                                 Employed part-time
# 9                                 Employed full-time
#
#                                              Country       US_State  \
# 0                                           Slovakia            NaN
# 1                                        Netherlands            NaN
# 2                                 Russian Federation            NaN
# 3                                            Austria            NaN
# 4  United Kingdom of Great Britain and Northern I...            NaN
# 5                           United States of America        Georgia
# 6                           United States of America  New Hampshire
# 7                                           Malaysia            NaN
# 8                                              India            NaN
# 9                                             Sweden            NaN
#
#   UK_Country                                            EdLevel  \
# 0        NaN  Secondary school (e.g. American high school, G...
# 1        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4    England    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6        NaN  Secondary school (e.g. American high school, G...
# 7        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#       Age1stCode                                          LearnCode YearsCode  \
# 0  18 - 24 years  Coding Bootcamp;Other online resources (ex: vi...       NaN
# 1  11 - 17 years  Other online resources (ex: videos, blogs, etc...         7
# 2  11 - 17 years  Other online resources (ex: videos, blogs, etc...       NaN
# 3  11 - 17 years                                                NaN       NaN
# 4   5 - 10 years                            Friend or family member        17
# 5  11 - 17 years  Other online resources (ex: videos, blogs, etc...       NaN
# 6  11 - 17 years  Other online resources (ex: videos, blogs, etc...         3
# 7  11 - 17 years             School;Online Courses or Certification         4
# 8  18 - 24 years                                    Coding Bootcamp         6
# 9  11 - 17 years                                             School         7
#
#    ...                Age             Gender Trans                Sexuality  \
# 0  ...    25-34 years old                Man    No  Straight / Heterosexual
# 1  ...    18-24 years old                Man    No  Straight / Heterosexual
# 2  ...    18-24 years old                Man    No        Prefer not to say
# 3  ...    35-44 years old                Man    No  Straight / Heterosexual
# 4  ...    25-34 years old                Man    No                      NaN
# 5  ...    18-24 years old  Prefer not to say    No  Straight / Heterosexual
# 6  ...  Prefer not to say  Prefer not to say    No                      NaN
# 7  ...    18-24 years old              Woman    No  Straight / Heterosexual
# 8  ...    25-34 years old                Man    No                      NaN
# 9  ...    25-34 years old                Man    No  Straight / Heterosexual
#
#                                            Ethnicity  \
# 0                       White or of European descent
# 1                       White or of European descent
# 2                                  Prefer not to say
# 3                       White or of European descent
# 4                       White or of European descent
# 5                                  Prefer not to say
# 6                                       I don't know
# 7  White or of European descent;Multiracial;South...
# 8                                        South Asian
# 9                       White or of European descent
#
#                  Accessibility  \
# 0            None of the above
# 1            None of the above
# 2            None of the above
# 3  I am deaf / hard of hearing
# 4            None of the above
# 5            None of the above
# 6            None of the above
# 7            None of the above
# 8                          NaN
# 9            None of the above
#
#                                         MentalHealth           SurveyLength  \
# 0                                  None of the above  Appropriate in length
# 1                                  None of the above  Appropriate in length
# 2                                  None of the above  Appropriate in length
# 3                                                NaN  Appropriate in length
# 4                                                NaN  Appropriate in length
# 5  I have a concentration and/or memory disorder ...               Too long
# 6                                  None of the above  Appropriate in length
# 7                                  None of the above  Appropriate in length
# 8  I have a concentration and/or memory disorder ...  Appropriate in length
# 9                                  None of the above  Appropriate in length
#
#                    SurveyEase ConvertedCompYearly
# 0                        Easy             62268.0
# 1                        Easy                 NaN
# 2                        Easy                 NaN
# 3  Neither easy nor difficult                 NaN
# 4                        Easy                 NaN
# 5  Neither easy nor difficult                 NaN
# 6  Neither easy nor difficult                 NaN
# 7                        Easy                 NaN
# 8                        Easy                 NaN
# 9  Neither easy nor difficult             51552.0
#
# [10 rows x 48 columns]

# %%
schema_df.iloc[3:]
# Out:
#        qid               qname  \
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# 29   QID91                  S4
# 30  QID266          NEWSOSites
# 31  QID100         SOVisitFreq
# 32  QID101           SOAccount
# 33  QID102          SOPartFreq
# 34  QID106              SOComm
# 35  QID267       NEWOtherComms
# 36  QID268  NEWOtherCommsNames
# 37  QID121                  S5
# 38  QID127                 Age
# 39  QID122              Gender
# 40  QID153               Trans
# 41  QID136           Sexuality
# 42  QID126           Ethnicity
# 43  QID124       Accessibility
# 44  QID125        MentalHealth
# 45  QID131                  S6
# 46  QID132        SurveyLength
# 47  QID133          SurveyEase
#
#                                              question  force_resp    type  \
# 3   Which of the following options best describes ...        True      MC
# 4   Which of the following best describes your cur...       False      MC
# 5   Where do you live? <span style="font-weight: b...        True      MC
# 6   <p>In which state or territory of the USA do y...       False      MC
# 7   In which part of the United Kingdom do you liv...       False      MC
# 8   <span style="font-size:22px; font-family: aria...       False      DB
# 9   Which of the following best describes the high...       False      MC
# 10  At what age did you write your first line of c...       False      MC
# 11  How did you learn to code? Select all that apply.       False      MC
# 12  Including any education, how many years have y...       False      MC
# 13  NOT including education, how many years have y...       False      MC
# 14  Which of the following describes your current ...       False      MC
# 15  Approximately how many people are employed by ...       False      MC
# 16  Which currency do you use day-to-day? If your ...        True      MC
# 17  What is your current total compensation (salar...       False      TE
# 18   Is that compensation weekly, monthly, or yearly?       False      MC
# 19  <span style="font-size:22px; font-family: aria...       False      DB
# 20  Which <b>programming, scripting, and markup la...       False  Matrix
# 21  Which <b>database environments </b>have you do...       False  Matrix
# 22  Which <b>cloud platforms</b> have you done ext...       False  Matrix
# 23  Which <strong>web frameworks </strong><span st...       False  Matrix
# 24  Which <b>other frameworks and libraries</b> ha...       False  Matrix
# 25  Which <strong>tools</strong> have you done ext...       False  Matrix
# 26  Which <strong>development environments</strong...       False  Matrix
# 27  What is the primary operating system in which ...       False      MC
# 28  What do you do when you get stuck on a problem...       False      MC
# 29  <span style="font-size:22px; font-family: aria...       False      DB
# 30  Which of the following Stack Overflow sites ha...       False      MC
# 31  How frequently would you say you visit Stack O...       False      MC
# 32              Do you have a Stack Overflow account?       False      MC
# 33  How frequently would you say you participate i...       False      MC
# 34  Do you consider yourself a member of the Stack...       False      MC
# 35  Are you a member of any other online developer...       False      MC
# 36  Please name up to 5 other online developer com...       False  Matrix
# 37  <span style="font-size:22px; font-family: aria...       False      DB
# 38                                  What is your age?       False      MC
# 39  Which of the following describe you, if any? P...       False      MC
# 40                    Do you identify as transgender?       False      MC
# 41  Which of the following describe you, if any? P...       False      MC
# 42  Which of the following describe you, if any? P...       False      MC
# 43  Which of the following describe you, if any? P...       False      MC
# 44  Which of the following describe you, if any? P...       False      MC
# 45  <span style="font-size:22px;"><strong>Final Qu...       False      DB
# 46  How do you feel about the length of the survey...       False      MC
# 47  How easy or difficult was this survey to compl...       False      MC
#
#    selector
# 3      SAVR
# 4      MAVR
# 5        DL
# 6        DL
# 7        DL
# 8        TB
# 9      SAVR
# 10     MAVR
# 11     MAVR
# 12       DL
# 13       DL
# 14     MAVR
# 15     MAVR
# 16       SB
# 17       SL
# 18     MAVR
# 19       TB
# 20   Likert
# 21   Likert
# 22   Likert
# 23   Likert
# 24   Likert
# 25   Likert
# 26   Likert
# 27     SAVR
# 28     MAVR
# 29       TB
# 30     MAVR
# 31     MAVR
# 32     MAVR
# 33     MAVR
# 34     MAVR
# 35     MAVR
# 36   Likert
# 37       TB
# 38     MAVR
# 39     MAVR
# 40     MAVR
# 41     MAVR
# 42     MAVR
# 43     MAVR
# 44     MAVR
# 45       TB
# 46     MAVR
# 47     MAVR

# %%
schema_df.shape
# Out:
# (48, 6)

# %%
df.shape
# Out:
# (83439, 48)

# %%
qn = (schema_df['qname']=='NEWOtherComms')

# %%
schema_df.loc[qn,'question']
# Out:
# 35    Are you a member of any other online developer...
# Name: question, dtype: object

# %%
pd.set_option('display.max_columns',df.shape[1])
#pd.set_option('display.latex.repr',False)
pd.set_option('display.max_rows',100)

# %%
filt = (df['Country']=='Poland')
df.loc[filt,'Country'].value_counts()#.tolist()#(normalize=True)
# Out:
# Poland    1805
# Name: Country, dtype: int64

# %%
df.loc[0:,'Age'].value_counts(normalize=True)
# Out:
# 25-34 years old       0.395209
# 18-24 years old       0.254748
# 35-44 years old       0.184244
# 45-54 years old       0.066402
# Under 18 years old    0.065237
# 55-64 years old       0.022073
# Prefer not to say     0.006978
# 65 years or older     0.005109
# Name: Age, dtype: float64

# %%
df.loc[0:20000,'Age'].tolist()
# Out:
# ['25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Prefer not to say',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Prefer not to say',
#  '45-54 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '65 years or older',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '65 years or older',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  nan,
#  '18-24 years old',
#  '45-54 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '25-34 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  'Prefer not to say',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '55-64 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  nan,
#  'Under 18 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '55-64 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '55-64 years old',
#  '35-44 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  nan,
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '65 years or older',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '55-64 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '55-64 years old',
#  '55-64 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  nan,
#  '55-64 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '55-64 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '55-64 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Prefer not to say',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '65 years or older',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '45-54 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '55-64 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '65 years or older',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '55-64 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '45-54 years old',
#  '35-44 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  'Under 18 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  nan,
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  'Under 18 years old',
#  '18-24 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  nan,
#  '18-24 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '55-64 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  'Under 18 years old',
#  'Under 18 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '35-44 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '25-34 years old',
#  '35-44 years old',
#  '18-24 years old',
#  'Under 18 years old',
#  '55-64 years old',
#  '25-34 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '45-54 years old',
#  '18-24 years old',
#  '18-24 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '25-34 years old',
#  '18-24 years old',
#  ...]

# %%
df.loc[50:60,['Age1stCode','Age']]
# Out:
#        Age1stCode                 Age
# 50  18 - 24 years     25-34 years old
# 51  11 - 17 years     25-34 years old
# 52  11 - 17 years     25-34 years old
# 53  18 - 24 years     25-34 years old
# 54  25 - 34 years     25-34 years old
# 55   5 - 10 years     35-44 years old
# 56  18 - 24 years     25-34 years old
# 57   5 - 10 years     35-44 years old
# 58  11 - 17 years     25-34 years old
# 59   5 - 10 years  Under 18 years old
# 60  11 - 17 years     18-24 years old

# %%
df.set_index('ResponseId',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.iloc[0]
# Out:
# ResponseId                                                                      1
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# OrgSize                                                        20 to 99 employees
# Currency                                                        EUR European Euro
# CompTotal                                                                  4800.0
# CompFreq                                                                  Monthly
# LanguageHaveWorkedWith              C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# LanguageWantToWorkWith                                                      Swift
# DatabaseHaveWorkedWith                                          PostgreSQL;SQLite
# DatabaseWantToWorkWith                                                     SQLite
# PlatformHaveWorkedWith                                                        NaN
# PlatformWantToWorkWith                                                        NaN
# WebframeHaveWorkedWith                                            Laravel;Symfony
# WebframeWantToWorkWith                                                        NaN
# MiscTechHaveWorkedWith                                                        NaN
# MiscTechWantToWorkWith                                                        NaN
# ToolsTechHaveWorkedWith                                                       NaN
# ToolsTechWantToWorkWith                                                       NaN
# NEWCollabToolsHaveWorkedWith                                       PHPStorm;Xcode
# NEWCollabToolsWantToWorkWith                                           Atom;Xcode
# OpSys                                                                       MacOS
# NEWStuck                        Call a coworker or friend;Visit Stack Overflow...
# NEWSOSites                                                         Stack Overflow
# SOVisitFreq                                                Multiple times per day
# SOAccount                                                                     Yes
# SOPartFreq                                        A few times per month or weekly
# SOComm                                                            Yes, definitely
# NEWOtherComms                                                                  No
# Age                                                               25-34 years old
# Gender                                                                        Man
# Trans                                                                          No
# Sexuality                                                 Straight / Heterosexual
# Ethnicity                                            White or of European descent
# Accessibility                                                   None of the above
# MentalHealth                                                    None of the above
# SurveyLength                                                Appropriate in length
# SurveyEase                                                                   Easy
# ConvertedCompYearly                                                       62268.0
# Name: 0, dtype: object

# %%
df['Country']
# Out:
# 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
#filt = (df['LanguageHaveWorkedWith']=='Python')

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
countries=['Slovakia','Poland','Russian Federation']

# %%
filts = (df['Country'].isin(countries)) & ~(df['LanguageHaveWorkedWith'].str.contains('Python', na=False)) &( df['Age'].between('25-34 years old','35-44 years old'))

# %%
# .isin(countries)    .str.contains('Python')
filt = (df['Country'].isin(countries))

# %%
df.loc[filts, ['LanguageHaveWorkedWith','Country','Age']]  #sort_index( ascending=True)
# Out:
#                                   LanguageHaveWorkedWith             Country  \
# 0          C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift            Slovakia
# 29                                       Delphi;Java;SQL  Russian Federation
# 32                       C++;HTML/CSS;JavaScript;PHP;SQL              Poland
# 135    Bash/Shell;C;HTML/CSS;Java;JavaScript;Node.js;...            Slovakia
# 146                    C++;Java;Kotlin;Objective-C;Swift  Russian Federation
# ...                                                  ...                 ...
# 83108                             Bash/Shell;C++;Go;Perl  Russian Federation
# 83110                                    Java;Kotlin;SQL              Poland
# 83203                            Bash/Shell;C#;Ruby;Rust              Poland
# 83294                                        Node.js;PHP  Russian Federation
# 83324                                HTML/CSS;JavaScript              Poland
#
#                    Age
# 0      25-34 years old
# 29     35-44 years old
# 32     25-34 years old
# 135    25-34 years old
# 146    25-34 years old
# ...                ...
# 83108  35-44 years old
# 83110  25-34 years old
# 83203  25-34 years old
# 83294  25-34 years old
# 83324  25-34 years old
#
# [1358 rows x 3 columns]

# %%
ff= (df['Country']=='Poland') & (df['LanguageHaveWorkedWith'].str.contains('Python'))
df.loc[ff,'Age'].value_counts()
# Out:
# 25-34 years old       306
# 18-24 years old       285
# 35-44 years old       118
# Under 18 years old     79
# 45-54 years old        15
# 55-64 years old         2
# Prefer not to say       2
# 65 years or older       1
# Name: Age, dtype: int64

# %%
df.at[32,'Country'] = 'Olkuszanin'

# %%
def yesOrNo(item):
    if item=='Yes': item=True
    else: item=False
    return item

# %%
df['NEWOtherComms']=df['NEWOtherComms'].apply(yesOrNo)

# %%
df['NEWOtherComms']=df['NEWOtherComms'].map({True:'Yeeep',False:'Nope'})

# %%
df['OpSys'].value_counts()
# Out:
# Windows                              37758
# Linux-based                          21088
# MacOS                                20984
# Windows Subsystem for Linux (WSL)     2743
# Other (please specify):                575
# BSD                                    146
# Name: OpSys, dtype: int64

# %%
df['ConvertedCompYearly'].median()
# Out:
# 56211.0

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
country = df.groupby(['Country'])

# %%
country.get_group('Poland')
# Out:
#        ResponseId                                         MainBranch  \
# 76             77  I am not primarily a developer, but I write co...
# 97             98                     I am a developer by profession
# 115           116             I am a student who is learning to code
# 138           139                     I am a developer by profession
# 182           183                     I am a developer by profession
# ...           ...                                                ...
# 83110       83111                     I am a developer by profession
# 83145       83146                     I am a developer by profession
# 83203       83204                     I am a developer by profession
# 83264       83265  I am not primarily a developer, but I write co...
# 83324       83325                     I am a developer by profession
#
#                                               Employment Country US_State  \
# 76                                    Employed full-time  Poland      NaN
# 97                                    Employed full-time  Poland      NaN
# 115                                   Student, full-time  Poland      NaN
# 138    Independent contractor, freelancer, or self-em...  Poland      NaN
# 182                                   Employed full-time  Poland      NaN
# ...                                                  ...     ...      ...
# 83110  Independent contractor, freelancer, or self-em...  Poland      NaN
# 83145  Independent contractor, freelancer, or self-em...  Poland      NaN
# 83203                                 Employed full-time  Poland      NaN
# 83264                                 Student, full-time  Poland      NaN
# 83324  Independent contractor, freelancer, or self-em...  Poland      NaN
#
#       UK_Country                                            EdLevel  \
# 76           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 97           NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 115          NaN  Secondary school (e.g. American high school, G...
# 138          NaN  Some college/university study without earning ...
# 182          NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...          ...                                                ...
# 83110        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83145        NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 83203        NaN       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 83264        NaN                          Primary/elementary school
# 83324        NaN  Secondary school (e.g. American high school, G...
#
#           Age1stCode                                          LearnCode  \
# 76     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 97     11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 115     5 - 10 years                            Other (please specify):
# 138    18 - 24 years                                       Online Forum
# 182    11 - 17 years                            Other (please specify):
# ...              ...                                                ...
# 83110  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83145  18 - 24 years  Coding Bootcamp;School;Online Courses or Certi...
# 83203   5 - 10 years     Other (please specify):;Books / Physical media
# 83264  11 - 17 years  Other online resources (ex: videos, blogs, etc...
# 83324   5 - 10 years  Other online resources (ex: videos, blogs, etc...
#
#       YearsCode YearsCodePro  \
# 76           12            8
# 97           10            4
# 115           4          NaN
# 138           5            3
# 182           6            3
# ...         ...          ...
# 83110        10            3
# 83145        10            7
# 83203        25            8
# 83264         4          NaN
# 83324        18            6
#
#                                                  DevType  \
# 76     Developer, front-end;Developer, full-stack;Dev...
# 97     Developer, front-end;Developer, full-stack;Dev...
# 115                                                  NaN
# 138    Developer, front-end;Developer, full-stack;Eng...
# 182                Developer, back-end;DevOps specialist
# ...                                                  ...
# 83110                                Developer, back-end
# 83145  Developer, full-stack;Developer, back-end;Educ...
# 83203                                     Engineer, data
# 83264                                                NaN
# 83324  Developer, mobile;Developer, front-end;Develop...
#
#                         OrgSize           Currency  CompTotal CompFreq  \
# 76     5,000 to 9,999 employees  PLN\tPolish zloty    15000.0  Monthly
# 97             2 to 9 employees  PLN\tPolish zloty     9000.0  Monthly
# 115                         NaN                NaN        NaN      NaN
# 138            2 to 9 employees  PLN\tPolish zloty    16000.0  Monthly
# 182        100 to 499 employees  PLN\tPolish zloty     5500.0  Monthly
# ...                         ...                ...        ...      ...
# 83110                       NaN  PLN\tPolish zloty    14000.0      NaN
# 83145      100 to 499 employees  PLN\tPolish zloty    24000.0  Monthly
# 83203      100 to 499 employees  PLN\tPolish zloty    14500.0  Monthly
# 83264                       NaN                NaN        NaN      NaN
# 83324          2 to 9 employees  PLN\tPolish zloty   120000.0   Yearly
#
#                                   LanguageHaveWorkedWith  \
# 76     Bash/Shell;C#;Dart;Delphi;Go;HTML/CSS;Java;Jav...
# 97        HTML/CSS;JavaScript;Node.js;PHP;SQL;TypeScript
# 115    Bash/Shell;C#;C++;HTML/CSS;JavaScript;PowerShe...
# 138              Go;JavaScript;Python;SQL;TypeScript;VBA
# 182     C;C++;Delphi;Go;HTML/CSS;Perl;Python;R;Ruby;Rust
# ...                                                  ...
# 83110                                    Java;Kotlin;SQL
# 83145              Bash/Shell;JavaScript;Python;Ruby;SQL
# 83203                            Bash/Shell;C#;Ruby;Rust
# 83264                C#;HTML/CSS;Java;Matlab;Node.js;SQL
# 83324                                HTML/CSS;JavaScript
#
#                                   LanguageWantToWorkWith  \
# 76                                                   NaN
# 97                HTML/CSS;JavaScript;Node.js;TypeScript
# 115    Bash/Shell;C#;C++;HTML/CSS;JavaScript;Python;T...
# 138                 JavaScript;Python;SQL;TypeScript;VBA
# 182                              Go;HTML/CSS;Python;Rust
# ...                                                  ...
# 83110                                   Java;Kotlin;Rust
# 83145                         Bash/Shell;Python;Ruby;SQL
# 83203                                            C#;Rust
# 83264                                           Java;SQL
# 83324             HTML/CSS;JavaScript;Node.js;TypeScript
#
#                                   DatabaseHaveWorkedWith  \
# 76     Firebase;Microsoft SQL Server;MongoDB;MySQL;Po...
# 97              Firebase;MongoDB;MySQL;PostgreSQL;SQLite
# 115                                                  NaN
# 138    Elasticsearch;MariaDB;Microsoft SQL Server;Mon...
# 182     DynamoDB;MariaDB;MongoDB;MySQL;PostgreSQL;SQLite
# ...                                                  ...
# 83110                                   MySQL;PostgreSQL
# 83145  DynamoDB;Elasticsearch;MariaDB;MySQL;PostgreSQ...
# 83203                           MongoDB;PostgreSQL;Redis
# 83264          Firebase;MariaDB;MongoDB;MySQL;PostgreSQL
# 83324                                           Firebase
#
#                                   DatabaseWantToWorkWith  \
# 76                                                   NaN
# 97                                                   NaN
# 115                                                  NaN
# 138    Elasticsearch;MariaDB;Microsoft SQL Server;Mon...
# 182            DynamoDB;MariaDB;MongoDB;MySQL;PostgreSQL
# ...                                                  ...
# 83110                          Elasticsearch;MySQL;Redis
# 83145  DynamoDB;Elasticsearch;Firebase;MySQL;PostgreS...
# 83203                                   PostgreSQL;Redis
# 83264                                      MongoDB;MySQL
# 83324                        Firebase;MongoDB;PostgreSQL
#
#                               PlatformHaveWorkedWith   PlatformWantToWorkWith  \
# 76             Google Cloud Platform;Microsoft Azure    Google Cloud Platform
# 97     AWS;DigitalOcean;Google Cloud Platform;Heroku                      NaN
# 115                                              NaN                      NaN
# 138        AWS;Google Cloud Platform;Microsoft Azure                      AWS
# 182                                              AWS                      AWS
# ...                                              ...                      ...
# 83110                                            NaN                      NaN
# 83145                        AWS;DigitalOcean;Heroku  AWS;DigitalOcean;Heroku
# 83203          Google Cloud Platform;Microsoft Azure                      NaN
# 83264         AWS;DigitalOcean;Google Cloud Platform             DigitalOcean
# 83324                                            NaN                      NaN
#
#                                   WebframeHaveWorkedWith  \
# 76     Angular;Angular.js;ASP.NET;ASP.NET Core ;Djang...
# 97                                      Laravel;React.js
# 115                                                  NaN
# 138          Django;FastAPI;Flask;Gatsby;jQuery;React.js
# 182                                         Django;Flask
# ...                                                  ...
# 83110                                             Spring
# 83145                             React.js;Ruby on Rails
# 83203                                                NaN
# 83264                                           React.js
# 83324          Angular;Angular.js;jQuery;React.js;Vue.js
#
#         WebframeWantToWorkWith  \
# 76                         NaN
# 97                    React.js
# 115                        NaN
# 138    Django;FastAPI;React.js
# 182                        NaN
# ...                        ...
# 83110                   Spring
# 83145            Ruby on Rails
# 83203                      NaN
# 83264                      NaN
# 83324  Express;Gatsby;React.js
#
#                                   MiscTechHaveWorkedWith  \
# 76     .NET Framework;.NET Core / .NET 5;Apache Spark...
# 97                                                   NaN
# 115                                                NumPy
# 138                                      NumPy;Pandas;Qt
# 182                                         NumPy;Pandas
# ...                                                  ...
# 83110                                                NaN
# 83145                                                NaN
# 83203                  .NET Framework;.NET Core / .NET 5
# 83264                  .NET Framework;.NET Core / .NET 5
# 83324                                       React Native
#
#                   MiscTechWantToWorkWith      ToolsTechHaveWorkedWith  \
# 76                                   NaN          Docker;Git;Unity 3D
# 97                                   NaN    Docker;Git;Terraform;Yarn
# 115                                NumPy                          Git
# 138                                  NaN      Ansible;Docker;Git;Yarn
# 182                               Pandas         Docker;Git;Terraform
# ...                                  ...                          ...
# 83110                                NaN           Ansible;Docker;Git
# 83145                                NaN        Docker;Git;Kubernetes
# 83203  .NET Framework;.NET Core / .NET 5  Ansible;Docker;Git;Unity 3D
# 83264                                NaN   Git;Unity 3D;Unreal Engine
# 83324               Flutter;React Native                          Git
#
#                    ToolsTechWantToWorkWith  \
# 76                                     NaN
# 97                              Docker;Git
# 115                    Docker;Git;Unity 3D
# 138                Ansible;Docker;Git;Yarn
# 182                   Docker;Git;Terraform
# ...                                    ...
# 83110                   Ansible;Docker;Git
# 83145                Docker;Git;Kubernetes
# 83203                                  Git
# 83264                                  Git
# 83324  Docker;Git;Kubernetes;Unreal Engine
#
#                             NEWCollabToolsHaveWorkedWith  \
# 76     Android Studio;Eclipse;NetBeans;Notepad++;Visu...
# 97                                Vim;Visual Studio Code
# 115                                   Visual Studio Code
# 138                                              PyCharm
# 182    IntelliJ;Neovim;PyCharm;Sublime Text;Vim;Webstorm
# ...                                                  ...
# 83110  Android Studio;Atom;IntelliJ;Sublime Text;Webs...
# 83145  Atom;RubyMine;Sublime Text;Vim;Visual Studio Code
# 83203     IntelliJ;Rider;Sublime Text;Visual Studio Code
# 83264  Atom;Notepad++;Sublime Text;Visual Studio;Visu...
# 83324  Android Studio;Atom;Sublime Text;Visual Studio...
#
#                          NEWCollabToolsWantToWorkWith        OpSys  \
# 76                                                NaN  Linux-based
# 97                                 Visual Studio Code      Windows
# 115                                               NaN      Windows
# 138                                           PyCharm  Linux-based
# 182                   Neovim;PyCharm;Sublime Text;Vim  Linux-based
# ...                                               ...          ...
# 83110             Atom;IntelliJ;Sublime Text;Webstorm  Linux-based
# 83145                 RubyMine;Vim;Visual Studio Code        MacOS
# 83203  IntelliJ;Rider;Sublime Text;Visual Studio Code  Linux-based
# 83264                              Visual Studio Code      Windows
# 83324         Android Studio;Visual Studio Code;Xcode        MacOS
#
#                                                 NEWStuck  \
# 76     Call a coworker or friend;Visit Stack Overflow...
# 97                        Visit Stack Overflow;Google it
# 115                       Visit Stack Overflow;Google it
# 138    Call a coworker or friend;Visit Stack Overflow...
# 182    Visit Stack Overflow;Go for a walk or other ph...
# ...                                                  ...
# 83110  Call a coworker or friend;Visit Stack Overflow...
# 83145  Call a coworker or friend;Visit Stack Overflow...
# 83203  Call a coworker or friend;Visit Stack Overflow...
# 83264  Call a coworker or friend;Visit Stack Overflow...
# 83324  Call a coworker or friend;Visit Stack Overflow...
#
#                           NEWSOSites                      SOVisitFreq  \
# 76     Stack Overflow;Stack Exchange           Multiple times per day
# 97     Stack Overflow;Stack Exchange           Multiple times per day
# 115    Stack Overflow;Stack Exchange  A few times per month or weekly
# 138    Stack Overflow;Stack Exchange           Multiple times per day
# 182                   Stack Overflow           Multiple times per day
# ...                              ...                              ...
# 83110  Stack Overflow;Stack Exchange            Daily or almost daily
# 83145                 Stack Overflow             A few times per week
# 83203  Stack Overflow;Stack Exchange           Multiple times per day
# 83264                 Stack Overflow            Daily or almost daily
# 83324  Stack Overflow;Stack Exchange           Multiple times per day
#
#       SOAccount                                         SOPartFreq  \
# 76          Yes                              Daily or almost daily
# 97          Yes  I have never participated in Q&A on Stack Over...
# 115         Yes                Less than once per month or monthly
# 138         Yes                Less than once per month or monthly
# 182         Yes                             Multiple times per day
# ...         ...                                                ...
# 83110       Yes                Less than once per month or monthly
# 83145       Yes                Less than once per month or monthly
# 83203       Yes                Less than once per month or monthly
# 83264        No                                                NaN
# 83324       Yes                Less than once per month or monthly
#
#                 SOComm NEWOtherComms                 Age Gender Trans  \
# 76     Yes, definitely          Nope     25-34 years old    Man    No
# 97       Yes, somewhat          Nope     18-24 years old    Man    No
# 115      Yes, somewhat         Yeeep  Under 18 years old    Man    No
# 138    Yes, definitely         Yeeep     25-34 years old    Man    No
# 182    Yes, definitely          Nope     35-44 years old    Man    No
# ...                ...           ...                 ...    ...   ...
# 83110   No, not really          Nope     25-34 years old    Man   NaN
# 83145   No, not really         Yeeep     25-34 years old    Man    No
# 83203   No, not really          Nope     25-34 years old    Man    No
# 83264   No, not really         Yeeep  Under 18 years old    Man    No
# 83324   No, not really          Nope     25-34 years old    Man    No
#
#                      Sexuality                                    Ethnicity  \
# 76     Straight / Heterosexual                 White or of European descent
# 97              Gay or Lesbian                 White or of European descent
# 115    Straight / Heterosexual                 White or of European descent
# 138    Straight / Heterosexual  White or of European descent;Middle Eastern
# 182    Straight / Heterosexual                 White or of European descent
# ...                        ...                                          ...
# 83110                      NaN                                          NaN
# 83145  Straight / Heterosexual                 White or of European descent
# 83203  Straight / Heterosexual                 White or of European descent
# 83264        Prefer not to say                 White or of European descent
# 83324  Straight / Heterosexual                 White or of European descent
#
#            Accessibility                                       MentalHealth  \
# 76     None of the above                                  None of the above
# 97     None of the above                                  None of the above
# 115                  NaN  I have a concentration and/or memory disorder ...
# 138    None of the above                                  None of the above
# 182    None of the above                                  None of the above
# ...                  ...                                                ...
# 83110                NaN                                                NaN
# 83145  None of the above                                  None of the above
# 83203  None of the above                                  None of the above
# 83264  None of the above                                  None of the above
# 83324  None of the above                                  None of the above
#
#                 SurveyLength                  SurveyEase  ConvertedCompYearly
# 76     Appropriate in length                        Easy              45564.0
# 97     Appropriate in length                        Easy              27336.0
# 115    Appropriate in length                        Easy                  NaN
# 138    Appropriate in length  Neither easy nor difficult              48600.0
# 182    Appropriate in length                        Easy              16704.0
# ...                      ...                         ...                  ...
# 83110               Too long                         NaN                  NaN
# 83145  Appropriate in length                        Easy              72900.0
# 83203  Appropriate in length                        Easy              44040.0
# 83264  Appropriate in length                        Easy                  NaN
# 83324              Too short                        Easy              30375.0
#
# [1804 rows x 48 columns]

# %%
country['OpSys'].value_counts()#.loc['Poland']
# Out:
# Country      OpSys
# Afghanistan  Windows                              28
#              Linux-based                          18
#              MacOS                                 6
#              Other (please specify):               6
#              BSD                                   2
#                                                   ..
# Zimbabwe     Windows                              20
#              Linux-based                           9
#              MacOS                                 5
#              Other (please specify):               1
#              Windows Subsystem for Linux (WSL)     1
# Name: OpSys, Length: 751, dtype: int64

# %%
 country['CompTotal'].median().sort_values(ascending=False).head(30)
# Out:
# Country
# Iran, Islamic Republic of...        80000000.0
# South Korea                         32000000.0
# Republic of Korea                   30000000.0
# Viet Nam                            18000000.0
# Indonesia                            9000000.0
# Japan                                5000000.0
# Colombia                             4500000.0
# Paraguay                             4450000.0
# Guinea                               4000000.0
# Uganda                               2500000.0
# Mongolia                             2400000.0
# Chile                                1800000.0
# Lao People's Democratic Republic     1800000.0
# Burkina Faso                         1200000.0
# United Republic of Tanzania          1150000.0
# Madagascar                           1035000.0
# Armenia                              1000000.0
# Uzbekistan                            976000.0
# Iceland                               800000.0
# Senegal                               800000.0
# Hungary                               740000.0
# Norway                                705000.0
# Iraq                                  650000.0
# India                                 622000.0
# Kazakhstan                            600000.0
# Djibouti                              535000.0
# Côte d'Ivoire                         450000.0
# Myanmar                               400000.0
# Malawi                                355000.0
# Rwanda                                300000.0
# Name: CompTotal, dtype: float64

# %%
country['CompTotal'].median().loc['United States of America']
# Out:
# 120000.0

# %%
country['CompTotal'].agg(['mean','median']).loc['Germany']
# Out:
# mean      48913.12228
# median    52600.00000
# Name: Germany, dtype: float64

# %%
pkp = country['LanguageHaveWorkedWith'].apply(lambda item: item.str.contains('Java').sum())

# %%
evr = df['Country'].value_counts()

# %%
ans = pd.concat([pkp,evr], axis='columns')

# %%
ans.rename(columns={'LanguageHaveWorkedWith':'UsingPython','Country': 'AllPeopleInCountry'}, inplace=True)

# %%
ans['%PeopleUsingPython'] = round(ans['UsingPython'] / ans['AllPeopleInCountry'] *100)

# %%
ans.loc['Poland']
# Out:
# UsingPython           1306.0
# AllPeopleInCountry    1804.0
# %PeopleUsingPython      72.0
# Name: Poland, dtype: float64

# %%
ans.sort_values(by='%PeopleUsingPython',ascending=False).head(100)
# Out:
#                                            UsingPython  AllPeopleInCountry  \
# Liechtenstein                                        1                   1
# Isle of Man                                          5                   5
# Burundi                                              5                   5
# Burkina Faso                                         4                   4
# Brunei Darussalam                                    1                   1
# Democratic Republic of the Congo                    10                  10
# Togo                                                 7                   7
# Dominica                                             1                   1
# Gambia                                               2                   2
# Guinea                                               2                   2
# Tuvalu                                               1                   1
# Chad                                                 2                   2
# Lao People's Democratic Republic                     4                   4
# Mauritania                                           5                   5
# Olkuszanin                                           1                   1
# Saint Kitts and Nevis                                1                   1
# San Marino                                           2                   2
# Guatemala                                           55                  58
# Côte d'Ivoire                                       16                  17
# Senegal                                             26                  28
# Cameroon                                            35                  38
# Namibia                                             11                  12
# Malawi                                              10                  11
# Jamaica                                             18                  20
# Swaziland                                            9                  10
# Sri Lanka                                          355                 396
# Bosnia and Herzegovina                             116                 130
# Tunisia                                            134                 150
# Bahrain                                             25                  28
# Venezuela, Bolivarian Republic of...                93                 104
# Honduras                                            21                  24
# Uganda                                              55                  63
# Ecuador                                             90                 103
# Mongolia                                            18                  21
# Syrian Arab Republic                                44                  51
# Morocco                                            174                 204
# Cuba                                                29                  34
# Costa Rica                                          65                  77
# Panama                                              26                  31
# Palestine                                           21                  25
# Dominican Republic                                  87                 104
# Luxembourg                                          43                  51
# The former Yugoslav Republic of Macedonia           45                  54
# Mozambique                                          10                  12
# Nigeria                                            339                 409
# Mexico                                             575                 695
# Congo, Republic of the...                           10                  12
# Zambia                                              18                  22
# Libyan Arab Jamahiriya                               9                  11
# Nepal                                              275                 337
# Kosovo                                              37                  45
# Bangladesh                                         578                 704
# Montenegro                                          14                  17
# Lebanon                                             91                 113
# Maldives                                            13                  16
# Sudan                                               22                  27
# Mauritius                                           25                  31
# El Salvador                                         26                  32
# Colombia                                           308                 381
# Philippines                                        309                 382
# Bhutan                                               4                   5
# Ghana                                               73                  91
# Argentina                                          468                 587
# Haiti                                                4                   5
# Peru                                               117                 147
# Suriname                                             4                   5
# Malta                                               33                  42
# Indonesia                                          499                 632
# Rwanda                                              27                  34
# Paraguay                                            37                  47
# Portugal                                           420                 530
# Kenya                                              204                 263
# Spain                                             1156                1485
# Pakistan                                           654                 838
# Republic of Moldova                                 43                  55
# Slovenia                                           183                 235
# Latvia                                              83                 107
# Jordan                                              56                  72
# Madagascar                                          14                  18
# Uruguay                                            113                 144
# Slovakia                                           194                 252
# Albania                                             56                  73
# Saudi Arabia                                       106                 137
# Bolivia                                             37                  48
# New Zealand                                        401                 522
# Romania                                            503                 650
# Serbia                                             239                 310
# Singapore                                          262                 339
# Belgium                                            539                 697
# Azerbaijan                                          49                  64
# United Republic of Tanzania                         33                  43
# Croatia                                            192                 250
# Italy                                             1284                1666
# South Africa                                       437                 571
# Viet Nam                                           295                 386
# Hong Kong (S.A.R.)                                 150                 198
# Malaysia                                           254                 333
# Kuwait                                              22                  29
# Turkey                                             801                1054
# Netherlands                                       1354                1772
#
#                                            %PeopleUsingPython
# Liechtenstein                                           100.0
# Isle of Man                                             100.0
# Burundi                                                 100.0
# Burkina Faso                                            100.0
# Brunei Darussalam                                       100.0
# Democratic Republic of the Congo                        100.0
# Togo                                                    100.0
# Dominica                                                100.0
# Gambia                                                  100.0
# Guinea                                                  100.0
# Tuvalu                                                  100.0
# Chad                                                    100.0
# Lao People's Democratic Republic                        100.0
# Mauritania                                              100.0
# Olkuszanin                                              100.0
# Saint Kitts and Nevis                                   100.0
# San Marino                                              100.0
# Guatemala                                                95.0
# Côte d'Ivoire                                            94.0
# Senegal                                                  93.0
# Cameroon                                                 92.0
# Namibia                                                  92.0
# Malawi                                                   91.0
# Jamaica                                                  90.0
# Swaziland                                                90.0
# Sri Lanka                                                90.0
# Bosnia and Herzegovina                                   89.0
# Tunisia                                                  89.0
# Bahrain                                                  89.0
# Venezuela, Bolivarian Republic of...                     89.0
# Honduras                                                 88.0
# Uganda                                                   87.0
# Ecuador                                                  87.0
# Mongolia                                                 86.0
# Syrian Arab Republic                                     86.0
# Morocco                                                  85.0
# Cuba                                                     85.0
# Costa Rica                                               84.0
# Panama                                                   84.0
# Palestine                                                84.0
# Dominican Republic                                       84.0
# Luxembourg                                               84.0
# The former Yugoslav Republic of Macedonia                83.0
# Mozambique                                               83.0
# Nigeria                                                  83.0
# Mexico                                                   83.0
# Congo, Republic of the...                                83.0
# Zambia                                                   82.0
# Libyan Arab Jamahiriya                                   82.0
# Nepal                                                    82.0
# Kosovo                                                   82.0
# Bangladesh                                               82.0
# Montenegro                                               82.0
# Lebanon                                                  81.0
# Maldives                                                 81.0
# Sudan                                                    81.0
# Mauritius                                                81.0
# El Salvador                                              81.0
# Colombia                                                 81.0
# Philippines                                              81.0
# Bhutan                                                   80.0
# Ghana                                                    80.0
# Argentina                                                80.0
# Haiti                                                    80.0
# Peru                                                     80.0
# Suriname                                                 80.0
# Malta                                                    79.0
# Indonesia                                                79.0
# Rwanda                                                   79.0
# Paraguay                                                 79.0
# Portugal                                                 79.0
# Kenya                                                    78.0
# Spain                                                    78.0
# Pakistan                                                 78.0
# Republic of Moldova                                      78.0
# Slovenia                                                 78.0
# Latvia                                                   78.0
# Jordan                                                   78.0
# Madagascar                                               78.0
# Uruguay                                                  78.0
# Slovakia                                                 77.0
# Albania                                                  77.0
# Saudi Arabia                                             77.0
# Bolivia                                                  77.0
# New Zealand                                              77.0
# Romania                                                  77.0
# Serbia                                                   77.0
# Singapore                                                77.0
# Belgium                                                  77.0
# Azerbaijan                                               77.0
# United Republic of Tanzania                              77.0
# Croatia                                                  77.0
# Italy                                                    77.0
# South Africa                                             77.0
# Viet Nam                                                 76.0
# Hong Kong (S.A.R.)                                       76.0
# Malaysia                                                 76.0
# Kuwait                                                   76.0
# Turkey                                                   76.0
# Netherlands                                              76.0

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('More than 50 years',51, inplace=True)

# %%
df['YearsCode'].replace('Less than 1 year',0, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38', 51,
#        '27', '41', '42', '35', '23', '28', '11', '37', '44', '43', '36',
#        '33', '45', '29', '50', '46', '32', '47', '49', '48'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %%
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
round(country['YearsCode'].mean().sort_values(ascending=False)).loc['Poland']
# Out:
# 11.0
